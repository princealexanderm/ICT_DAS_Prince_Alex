# %% [markdown]
# <a href="https://colab.research.google.com/github/princealexanderm/ICT_DAS_Prince_Alex/blob/main/Assignment_ICT_Case_study_python_flask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---

# %% [markdown]
# **Topic: Assignment-Case study wine quality** <br>
# **Date: 16/09/24**<br>
# **Data: Wine quality**

# %% [markdown]
# **Instructions:**
#
# Dear all,
#
# Welcome to Case Study #03 - Python Flask! Please find below the guidelines and instructions for completing this case study:
#
# Case Study on Python Flask: Using the given dataset, create a web application to take feature inputs from the user in a web page and print whether a person will purchase the product or not.
#
# Submission Requirements:
#
# Do a screen recording of all your codes which needs to be submitted.
# Follow the 'video submission guidelines' for submitting the video.
# Submit the complete files as a .zip in Paatshala.
# Do not include the video inside the .zip file.
# Keep your name as the file name.
#
#
# For the Case Study #03 - Python Flask, please ensure to submit the following in Paatshala:
#
# Google Drive link of recorded video (Provide necessary access).
# Complete files as a .zip file.
# The hosted website link.
# Please keep your name as the file name for easy identification.
#
#
# Guidelines for Recording the Video:
#
# Do a screen recording (with your audio explanation) of the work.
# Start recording with a short introduction of yourself (specify name and batch).
# Explain each step in detail during the recording.
# Save the recording to your Google Drive.
# Submit the Google Drive link in Paatshala along with all other specified documents.
# Use apps such as Free Cam, ACTIVE Presenter, Screencast-O-Matic, etc., for screen recording.
# The duration of the video must be a maximum of 7-8 minutes.
# Ensure proper access is given to view the link when sharing the Google Drive link.

# %% [markdown]
# # importing essential libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading data

# %%
df=pd.read_csv('/content/winequality-red.csv')
df.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 761             9.3             0.655         0.26             2.0      0.096
# 1172            9.7             0.420         0.46             2.1      0.074
# 1031            7.3             0.550         0.01             1.8      0.093
# 507            11.2             0.670         0.55             2.3      0.084
# 1037            7.3             0.910         0.10             1.8      0.074
# 816             9.8             0.510         0.19             3.2      0.081
# 1022            7.0             0.510         0.09             2.1      0.062
# 1138            7.5             0.410         0.15             3.7      0.104
# 665             9.4             0.590         0.14             2.0      0.084
# 141             8.3             0.715         0.15             1.8      0.089
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df['quality'].max()
# Out:
# 8

# %%
df['quality'].min()
# Out:
# 3

# %% [markdown]
# #Checking basic information

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# #Checking for missing values

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# #Checking unique values one by one

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df['fixed acidity'].unique()
# Out:
# array([ 7.4,  7.8, 11.2,  7.9,  7.3,  7.5,  6.7,  5.6,  8.9,  8.5,  8.1,
#         7.6,  6.9,  6.3,  7.1,  8.3,  5.2,  5.7,  8.8,  6.8,  4.6,  7.7,
#         8.7,  6.4,  6.6,  8.6, 10.2,  7. ,  7.2,  9.3,  8. ,  9.7,  6.2,
#         5. ,  4.7,  8.4, 10.1,  9.4,  9. ,  8.2,  6.1,  5.8,  9.2, 11.5,
#         5.4,  9.6, 12.8, 11. , 11.6, 12. , 15. , 10.8, 11.1, 10. , 12.5,
#        11.8, 10.9, 10.3, 11.4,  9.9, 10.4, 13.3, 10.6,  9.8, 13.4, 10.7,
#        11.9, 12.4, 12.2, 13.8,  9.1, 13.5, 10.5, 12.6, 14. , 13.7,  9.5,
#        12.7, 12.3, 15.6,  5.3, 11.3, 13. ,  6.5, 12.9, 14.3, 15.5, 11.7,
#        13.2, 15.9, 12.1,  5.1,  4.9,  5.9,  6. ,  5.5])

# %%
df['citric acid'].unique()
# Out:
# array([0.  , 0.04, 0.56, 0.06, 0.02, 0.36, 0.08, 0.29, 0.18, 0.19, 0.28,
#        0.51, 0.48, 0.31, 0.21, 0.11, 0.14, 0.16, 0.24, 0.07, 0.12, 0.25,
#        0.09, 0.3 , 0.2 , 0.22, 0.15, 0.43, 0.52, 0.23, 0.37, 0.26, 0.57,
#        0.4 , 0.49, 0.05, 0.54, 0.64, 0.7 , 0.47, 0.44, 0.17, 0.68, 0.53,
#        0.1 , 0.01, 0.55, 1.  , 0.03, 0.42, 0.33, 0.32, 0.35, 0.6 , 0.74,
#        0.58, 0.5 , 0.76, 0.46, 0.45, 0.38, 0.39, 0.66, 0.62, 0.67, 0.79,
#        0.63, 0.61, 0.71, 0.65, 0.59, 0.34, 0.69, 0.73, 0.72, 0.41, 0.27,
#        0.75, 0.13, 0.78])

# %%
df['volatile acidity'].unique()
# Out:
# array([0.7  , 0.88 , 0.76 , 0.28 , 0.66 , 0.6  , 0.65 , 0.58 , 0.5  ,
#        0.615, 0.61 , 0.62 , 0.56 , 0.59 , 0.32 , 0.22 , 0.39 , 0.43 ,
#        0.49 , 0.4  , 0.41 , 0.71 , 0.645, 0.675, 0.685, 0.655, 0.605,
#        0.38 , 1.13 , 0.45 , 0.67 , 0.52 , 0.935, 0.29 , 0.31 , 0.51 ,
#        0.42 , 0.63 , 0.69 , 0.735, 0.725, 0.705, 0.785, 0.75 , 0.625,
#        0.3  , 0.55 , 1.02 , 0.775, 0.9  , 0.545, 0.575, 0.33 , 0.54 ,
#        1.07 , 0.695, 1.33 , 0.745, 1.04 , 0.715, 0.415, 0.34 , 0.68 ,
#        0.95 , 0.53 , 0.64 , 0.885, 0.805, 0.73 , 0.37 , 0.835, 1.09 ,
#        0.57 , 0.44 , 0.635, 0.82 , 0.48 , 1.   , 0.21 , 0.35 , 0.975,
#        0.26 , 0.87 , 0.18 , 0.27 , 0.2  , 0.36 , 0.83 , 0.46 , 0.47 ,
#        0.77 , 0.815, 0.795, 0.665, 0.765, 0.24 , 0.85 , 0.84 , 0.96 ,
#        0.78 , 0.23 , 0.315, 0.365, 0.25 , 0.825, 0.72 , 0.595, 0.585,
#        0.915, 0.755, 0.845, 1.24 , 0.8  , 0.98 , 1.185, 0.92 , 1.035,
# ...

# %% [markdown]
# # Each column distribution

# %% [markdown]
# ## Target column

# %%
sns.histplot(df['quality'])
# Out:
# <Axes: xlabel='quality', ylabel='Count'>

# %% [markdown]
# #Checking basic statistics using histogram,Fequency graph

# %%
freqgraph = df.select_dtypes(include=['float','int'])
freqgraph.hist(figsize=(20,15),color='red')
plt.show()

# %% [markdown]
# #Checking for outliers

# %%
df.boxplot()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Checking correlation

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import seaborn as sns
corrmat=df.corr()
plt.subplots(figsize=(20,10))
sns.heatmap(corrmat,annot=True,cmap='YlGnBu',linewidth=0.2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# 1. Diagnonal is dark blue, its value is 1 as they are correlating with itself
# 2. See free sulphur dioxide vs total sulphur dioxide have 0.67 strong correlation. It means they have similar porperty. So we can remove one of the two column
# 3. Now we have to decide which one we have to drop
# 4. So we check correlation with target variable 'Quality' (last column)
# 5. Free sulphur dioxide has -0.051 correlation and total sulphur dioxide has -0.19 correlation with target variable 'quality'.
# 6. It means free sulphur dioxide has least correlation with quality compared with total sulphur dioxide. So we remove free sulphur dioxide.
# 7. Similarly 'density and fixed acidity' has strong correlation.
# 8. Density has -0.17 correlation with quality. Fixed acidity has 0.12 correlation with quality. Here -0.17 indicates more correlation. Hence we drop Fixed acidity
# 9. Similarly citric acid and fixed acidity. we drop fixed acidity
# 10. So we drop 'fixed acidity' and 'free sulphur dioxide'

# %%
df.drop(['fixed acidity','free sulfur dioxide'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    volatile acidity  citric acid  residual sugar  chlorides  \
# 0              0.70         0.00             1.9      0.076
# 1              0.88         0.00             2.6      0.098
# 2              0.76         0.04             2.3      0.092
# 3              0.28         0.56             1.9      0.075
# 4              0.70         0.00             1.9      0.076
#
#    total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                  34.0   0.9978  3.51       0.56      9.4        5
# 1                  67.0   0.9968  3.20       0.68      9.8        5
# 2                  54.0   0.9970  3.26       0.65      9.8        5
# 3                  60.0   0.9980  3.16       0.58      9.8        6
# 4                  34.0   0.9978  3.51       0.56      9.4        5

# %% [markdown]
# #completed preprocessing

# %% [markdown]
# #Split the table

# %%
X=df.drop('quality',axis=1)
y=df['quality']

# %%
X.head(3)
# Out:
#    volatile acidity  citric acid  residual sugar  chlorides  \
# 0              0.70         0.00             1.9      0.076
# 1              0.88         0.00             2.6      0.098
# 2              0.76         0.04             2.3      0.092
#
#    total sulfur dioxide  density    pH  sulphates  alcohol
# 0                  34.0   0.9978  3.51       0.56      9.4
# 1                  67.0   0.9968  3.20       0.68      9.8
# 2                  54.0   0.9970  3.26       0.65      9.8

# %%
y.head(3)
# Out:
# 0    5
# 1    5
# 2    5
# Name: quality, dtype: int64

# %% [markdown]
# #Split the data for training and testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
df.shape
# Out:
# (1599, 10)

# %%
X_test.shape
# Out:
# (320, 9)

# %% [markdown]
# #Selcting the model for regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
model=lr.fit(X_train,y_train)
y_pred=model.predict(X_test)

# %%
y_pred # these are the predicted y values for the last 20% of the x values
# Out:
# array([5.36974691, 5.0728262 , 5.63044404, 5.39362061, 5.70884204,
#        5.20819994, 5.10809386, 5.11953814, 5.75792865, 5.6684396 ,
#        6.15732085, 5.24166843, 5.53642993, 5.20701959, 5.41305093,
#        6.46584787, 5.1931579 , 5.60107812, 6.59026808, 5.32609011,
#        5.42405459, 5.19311338, 5.94034678, 6.38274474, 5.35511537,
#        5.42706257, 6.40998931, 5.37221789, 5.17938079, 6.18652135,
#        5.2804017 , 5.57421759, 5.78943986, 5.38647446, 5.45158482,
#        5.0733836 , 6.1643836 , 5.7012559 , 5.63344392, 6.18065549,
#        5.51769967, 5.30410361, 6.2064671 , 5.24146471, 5.88199572,
#        5.81975729, 6.43571829, 5.59722467, 5.15487629, 5.56887492,
#        5.19592694, 5.12361748, 5.5928918 , 6.4169157 , 5.01539244,
#        5.08531152, 5.99435607, 5.48808623, 5.82199652, 5.25000543,
#        5.64066739, 5.97818271, 5.2737515 , 5.33969845, 6.41575893,
#        5.37791194, 6.34388399, 5.30510884, 6.47462492, 5.3008133 ,
# ...

# %% [markdown]
# #Evaluating using mean squared error and r square

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 0.38838197522200363

# %%
r_result=r2_score(y_test,y_pred)
r_result
# Out:
# 0.4056947315002739

# %% [markdown]
# compare with the actual values

# %%
y_test.head(10)
# Out:
# 803     6
# 124     5
# 350     6
# 682     5
# 1326    6
# 976     5
# 1493    5
# 706     5
# 613     5
# 1587    6
# Name: quality, dtype: int64

# %% [markdown]
# first value is 6, lets check ww are getting it or not in the predictios

# %%
y_pred[0] #first value of y_pred
# Out:
# 5.369746906713322

# %% [markdown]
# or check with full data

# %%
X_train.head(5)
# Out:
#      volatile acidity  citric acid  residual sugar  chlorides  \
# 493             0.690         0.31             3.0      0.086
# 354             0.210         0.40             1.4      0.066
# 342             0.390         0.47             1.8      0.118
# 834             0.685         0.26             1.6      0.088
# 705             1.035         0.15             6.0      0.073
#
#      total sulfur dioxide  density    pH  sulphates  alcohol
# 493                  81.0  1.00020  3.48       0.74     11.6
# 354                 165.0  0.99120  3.25       0.59     11.9
# 342                  14.0  0.99820  3.30       0.75      9.8
# 834                  23.0  0.99694  3.32       0.47      9.4
# 705                  54.0  0.99900  3.37       0.49      9.9

# %%
y.head(3)
# Out:
# 0    5
# 1    5
# 2    5
# Name: quality, dtype: int64

# %%
pred_2=[[.690,0.31,3.0,0.086,81.0,1.00020,3.48,0.74,11.6]]
y_pred2=model.predict(pred_2)
y_pred2
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5.72097077])

# %% [markdown]
# we were expecting 5

# %% [markdown]
# #Convert machine learning algorithm to pickle file

# %%
import pickle
with open('model.pkl','wb') as model_file:
    pickle.dump(lr,model_file)

# %% [markdown]
# ---

# %% [markdown]
# # VS code

# %% [markdown]
# # 1. model.py

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.metrics import mean_squared_error,r2_score

file_name="winequality-red.csv"

df=pd.read_csv(file_name)

df.drop(['fixed acidity','free sulfur dioxide'],axis=1,inplace=True)

y=df['quality']
x=df.drop(['quality'],axis=1)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

lr=linear_model.LinearRegression()
lr.fit(x_train,y_train)

import pickle
with open('model.pkl','wb') as model_file:
  pickle.dump(lr,model_file)

# %% [markdown]
# # 2. app.py

# %%
import pandas as pd
from flask import Flask,render_template,request
import pickle
import numpy as np



app = Flask(__name__)

file_name="winequality-red.csv"

wine=pd.read_csv(file_name)

with open('model.pkl','rb') as model_file:
    clf_model = pickle.load(model_file)

@app.route('/')
def home():
    return render_template('first.html')

@app.route('/predict',methods=['POST'])
def predict():
    volatile_acidity = float(request.form['volatile_acidity'])
    citric_acid = float(request.form['citric_acid'])
    residual_sugar = float(request.form['residual_sugar'])
    chlorides = float(request.form['chlorides'])
    total_sulfur_dioxide = float(request.form['total_sulfur_dioxide'])
    density = float(request.form['density'])
    pH = float(request.form['pH'])
    sulphates = float(request.form['sulphates'])
    alcohol = float(request.form['alcohol'])

    input_features = np.array([[volatile_acidity,citric_acid,residual_sugar,chlorides,total_sulfur_dioxide,density,pH,sulphates,alcohol]])
    pred = clf_model.predict(input_features)

    target = pred[0]
    #species = wine.target_names[target]
    return render_template('first.html',pred_result = target)

if __name__=='__main__':
    app.run(debug=True)

# %% [markdown]
# # 3. first.html

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Wine Quality Prediction using ML_by Prince Alex</title>
    <link rel='stylesheet' type='text/css' href="../static/css/style.css">
</head>
<body>
    <h1>Wine Quality Prediction using ML_by Prince Alex</h1>
    <p><img align='right' src="../static/img/download.jpg" alt='Wine'>
    <form action="/predict" method="post">
        <label>volatile acidity : </label>
        <input type="text" name = volatile_acidity><br><br>

        <label>citric acid : </label>
        <input type="text" name = citric_acid><br><br>

        <label>residual sugar : </label>
        <input type="text" name = residual_sugar><br><br>

        <label>chlorides_ : </label>
        <input type="text" name = chlorides><br><br>

        <label>total sulfur dioxide : </label>
        <input type="text" name = total_sulfur_dioxide><br><br>

        <label>density_ : </label>
        <input type="text" name = density><br><br>

        <label>pH_ : </label>
        <input type="text" name = pH><br><br>

        <label>sulphates_ : </label>
        <input type="text" name = sulphates><br><br>

        <label>alcohol_ : </label>
        <input type="text" name = alcohol><br><br>

        <button type="submit">Predict</button><br><br>

        <h1>Prediction Result : {{pred_result}}</h1>

    </form>

</body>
</html>

# %% [markdown]
# # 4. style.css

# %%
body{
    font-family: 'Lucida Sans', 'Lucida Sans Regular', 'Lucida Grande', 'Lucida Sans Unicode', Geneva, Verdana, sans-serif;
    background-color: rgba(142, 9, 51, 0.249);
}

h1{
    text-align: center;
    margin-top: 80px;
    color:blue
}

form {
    margin-left: 200px;
    margin-right: 100px;
    margin-bottom: 40px;
}

label {
    display:block;
    margin-bottom: 5px;
    color:black
}



h2{
    text-align: center;
    color: red;
}

# %% [markdown]
# ---

# %% [markdown]
# #Steps carried out

# %% [markdown]
# 1. imported necessary modules
# 2. Load data
# 3. Checking for basic informatin
# 4. Check for null values and outliers
# 5. Statistics checking
# 6. Checking correlation
# 7. Based on correlation dropped, 'fixed acidity' and 'free sulpher dioxide'
# 8. Split the data into target data
# 9. Split the data for testing and training
# 10.Selecting Linear regression model
# 11. Evaluating model usng mean squared error and r2 score
# 12. Convert the data into pickle file

# %% [markdown]
# ---

# %% [markdown]
# 1. Created a folder called 'Assignment_Python Flask' in desktop
# 2. Moved the data 'winequality-red.csv' to this folder
# 3. In the address bar type 'cmd' to open vs code
# 4. In the cmd, type 'code .'
# 5. Create a file 'model.py'
# 6. Fill all the codes given above
# 7. Create a folder 'templates', create a file 'first.html'
# 8. Fill all the codes give above in it
# 9. create a file 'app.py', fill all the codes given above
# 10. Create a folder 'static'. create two folder inside it, 'css' and 'img'
# 11. Inside 'css', create a file 'style.css' and save a wine figure named 'download.jpg' in it
# 12. Open new terminal and run 'python app.py'

# %% [markdown]
# #Webpage

# %% [markdown]
# http://127.0.0.1:5000/predict

# %% [markdown]
# ![image.png](data:image/png;base64,...)
