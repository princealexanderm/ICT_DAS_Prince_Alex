# %% [markdown]
# <a href="https://colab.research.google.com/github/princealexanderm/ICT_DAS_Prince_Alex/blob/main/ICT_internship_employee_salary_prediction_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ICT Internship-Employee Salary Prediction- Prince Alex

# %% [markdown]
# ## Project Overview
# During this 4-week internship, the intern will analyze and model a dataset related to employee salary and job attributes, including factors like job title, job category, experience level, and work setting. The primary goal is to derive insights from this data and build a machine learning model to predict salary ranges. By the end of the internship, the intern will
# have deployed a Flask-based web application that enables users to input data and receive a salary prediction based on their parameters.

# %% [markdown]
# ---

# %% [markdown]
# ## Dataset Description
# The dataset( click here ) includes columns such as:
# - work_year: Year of the data record
# - job_title: Title of the job position ['Machine Learning Engineer  in office', 'Statistician  (Remote)',
#        'Machine Learning Engineer', 'Data Analyst  in office',
#        'Statistician', 'Data Scientist  (Remote)', 'Data Analyst',
#        'Data Engineer  in office', 'Data Scientist',
#        'Machine Learning Engineer  (Remote)', 'Data Engineer',
#        'Data Engineer  (Remote)', 'Data Scientist  in office',
#        'Data Analyst  (Remote)', 'Statistician  in office']
# - job_category: Category of the job position ['Analysis', 'ML/AI', 'Data Science', 'Engineering', 'nan']
# - salary_currency: Currency of the salary ['EUR', 'JPY', 'INR', nan, 'us dolars', 'GBP']
# - salary: Salary in the local currency
# - salary_in_usd: Salary in USD
# - employee_residence: Location of the employee’s residence ['US', 'JP (Japan)', 'UK', 'DE (Germany)', 'CN (China)', 'MX (Mexico)', 'IN (India)']
# - experience_level: Experience level of the employee ['MI (Mid Level)', 'EX (Expert)', 'SE (Senior Level)', nan, 'EN (Entry Level)']
# - employment_type: Type of employment ['CT (contract)', 'FL (Freelance)', 'FT (Full time)', 'PT (Part time)']
# - work_setting: The work setting ['Remote', 'Hybrid', 'In-person']
# - company_location: Location of the company ['DE', 'IN', 'CN', 'MX', 'UK', 'JP', 'US']
# - company_size: Size of the company (e.g., S, M, L)

# %% [markdown]
# ## Goals and Weekly Plan
# ### Week 1: Data Understanding, Cleaning, and EDA
#
# **Goal:** Familiarize with the dataset, clean and preprocess the data, and perform exploratory data analysis (EDA) to understand patterns and relationships.
# 1. Data Loading and Inspection:
#    - Load the dataset, examine columns, data types, and identify any missing or inconsistent values.
#    - Convert data types where necessary (e.g., dates, categorical encoding).
# 2. Data Cleaning:
#    - Handle missing values through imputation or removal.
#    - Standardize categorical values.
#    - Ensure all salary values are in USD for consistency in analysis.
# 3. Exploratory Data Analysis (EDA):
#    - Generate descriptive statistics.
#    - Plot distribution of salaries by job_category, experience_level, work_setting, and company_size.
# 4. Documentation:
#    - Summarize insights and challenges from the data cleaning and EDA phases.

# %% [markdown]
# ## Week 2: Feature Engineering and Model Selection
# **Goal:** Create new features to improve predictive power, select relevant features, and explore initial model types for predicting salaries.
# 1. Feature Engineering:
#    - Create additional features to improve model accuracy.
# 2. Feature Selection:
#    - Use correlation analysis, feature importance, and variance analysis to identify key features.
# 3. Model Selection and Testing:
#    - Start with a few basic regression models.
# 4. Initial Evaluation:
#    - Document findings for chosen models.

# %% [markdown]
# ## Week 3: Model Optimization and Flask App Development
# **Goal:** Improve model accuracy through hyperparameter tuning and begin building a Flask
# web application.
# 1. Model Tuning:
#    - Perform hyperparameter tuning on selected models.
# 2. Flask Application Development - Backend:
#    - Set up a Flask app structure and integrate the final model.
# 3. Testing:
#    - Test the Flask app locally.
# 4. Documentation:
#    - Document the model selection, tuning process, and initial Flask app architecture.

# %% [markdown]
# ## Week 4: Finalizing Flask App, UI Development, and Deployment
# **Goal:** Complete the web application with a user-friendly interface, deploy it, and create final
# documentation.
# 1. Flask Application Development - Frontend:
#    - Design a web interface for user input.
# 2. Integration and Testing:
#    - Connect frontend to Flask backend and perform end-to-end testing.
# 3.Deployment:
#   - Deploy the application using a platform like Pythonanywhere.
# 4. Final Documentation and Presentation:
#    - Compile a final report and prepare a demo.
#
# ## Expected Outcomes
# By the end of the internship, the intern will have:
#    - Developed a complete pipeline for analyzing, processing, and predicting salary data.
#    - Created a deployed Flask application that predicts salaries based on user inputs.
#    - Documented each phase and delivered a presentation demonstrating the project workflow and final application.

# %% [markdown]
# ---

# %% [markdown]
# # Week-1

# %% [markdown]
# #1.1 importing modules

# %% [markdown]
# Python has a vast ecosystem of libraries that support a wide range of applications, from data analysis and machine learning to web development and scientific computing.<br>
# To import Python libraries into your program, you use the import statement

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# Pandas: For data manipulation and analysis using DataFrames.<br>
# NumPy: For numerical computing and handling arrays.<br>
# Matplotlib: For creating static, interactive, and animated plots.<br>
# Seaborn: High-level interface for drawing attractive statistical graphics.<br>
# Scikit-learn (sklearn): For classical machine learning algorithms.<br>
# Scikit-learn documentation:https://scikit-learn.org/stable/

# %% [markdown]
# # 1.2 Loading data set

# %% [markdown]
# - The most common method to load a dataset in Pandas is using the read_csv() function.
# - The df.sample() function in Pandas is used to select a random sample of rows (or columns) from a DataFrame. It is helpful when you want to preview or test your data with a subset randomly selected from the original dataset.

# %%
df=pd.read_csv('/content/dsa_job - data_science_job.csv')
df.sample(10)
# Out:
#       work_year                             job_title  job_category  \
# 2493       2022               Data Analyst  in office   Engineering
# 966        2022                        Data Scientist      Analysis
# 3884       2021                          Data Analyst         ML/AI
# 2165       2020               Data Engineer  (Remote)         ML/AI
# 1517       2021             Data Scientist  in office   Engineering
# 2164       2021                          Statistician           NaN
# 877        2021  Machine Learning Engineer  in office           NaN
# 749        2021                Data Analyst  (Remote)         ML/AI
# 62         2021                          Data Analyst  Data Science
# 898        2021                          Statistician      Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 2493       us dolars   40114         113489                 DE
# 966              EUR   91684         122688                 UK
# ...

# %% [markdown]
# - Some 'salary' column contains -ve sign infront of the number

# %% [markdown]
# # 1.3 Shape of the data set

# %% [markdown]
# In Pandas, you can check the shape of a dataset (DataFrame or Series) using the .shape attribute. It returns a tuple representing the number of rows and columns in the DataFrame.

# %%
df.shape
# Out:
# (5000, 12)

# %% [markdown]
# Dataset consists of 5000 rows and 12 columns

# %% [markdown]
# # 1.4 Summary statistics of the DataFrame

# %% [markdown]
# The df.describe() function in Pandas provides a statistical summary of your DataFrame's numerical columns (by default). It is a quick way to get insights into the distribution, central tendency, and spread of your data.

# %%
df.describe()
# Out:
#         work_year         salary  salary_in_usd
# count  5000.00000    5000.000000    5000.000000
# mean   2020.97680  102046.307200  114076.995800
# std       0.81951   70853.626492   49113.807687
# min    2020.00000 -198754.000000   30016.000000
# 25%    2020.00000   64295.500000   71343.750000
# 50%    2021.00000  110636.000000  114167.000000
# 75%    2022.00000  153104.750000  156665.750000
# max    2022.00000  199924.000000  199985.000000

# %% [markdown]
# #1.5 Summary of the DataFrame

# %% [markdown]
# The df.info() function in Pandas provides a concise summary of a DataFrame. It is useful for understanding the structure and types of data in the DataFrame, including the number of non-null entries, data types, and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           5000 non-null   int64
#  1   job_title           5000 non-null   object
#  2   job_category        4500 non-null   object
#  3   salary_currency     4500 non-null   object
#  4   salary              5000 non-null   int64
#  5   salary_in_usd       5000 non-null   int64
#  6   employee_residence  5000 non-null   object
#  7   experience_level    4500 non-null   object
#  8   employment_type     5000 non-null   object
#  9   work_setting        5000 non-null   object
#  10  company_location    5000 non-null   object
#  11  company_size        4500 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 468.9+ KB

# %% [markdown]
# out of the 12 rows, only 3 is numerical type, 9 are object type

# %% [markdown]
# 1. work_year
# 2. salary
# 3. salary_in_usd
#
# are numerical datas

# %% [markdown]
# #1.6 Identify and count missing values in each column of a DataFrame

# %% [markdown]
# The df.isna().sum() function in Pandas is used to identify the number of missing (NaN) values in each column of a DataFrame. This is helpful for data cleaning and preprocessing tasks where you need to handle missing data.

# %%
df.isna().sum()
# Out:
# work_year               0
# job_title               0
# job_category          500
# salary_currency       500
# salary                  0
# salary_in_usd           0
# employee_residence      0
# experience_level      500
# employment_type         0
# work_setting            0
# company_location        0
# company_size          500
# dtype: int64

# %% [markdown]
# 4 columns contains missing values of 500 data which is 10% of the data

# %% [markdown]
# #1.7 Access the column labels of a DataFrame

# %% [markdown]
# The df.columns attribute in Pandas is used to get the labels of the columns in a DataFrame. This is helpful for understanding the structure of your DataFrame and for further data manipulation tasks.

# %%
df.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# #1.8 Return unique values in object type column of the dataframe

# %% [markdown]
# The df.nunique() function in Pandas is used to count the number of unique values in each column of a DataFrame. This is particularly helpful for understanding the variability within your data and for identifying columns that may need further analysis or processing.

# %%
df.nunique()
# Out:
# work_year                3
# job_title               15
# job_category             4
# salary_currency          5
# salary                4943
# salary_in_usd         4927
# employee_residence       7
# experience_level         4
# employment_type          4
# work_setting             3
# company_location         7
# company_size             3
# dtype: int64

# %% [markdown]
# ### 1.8.1 Unique values in year

# %%
df['work_year'].unique()
# Out:
# array([2022, 2020, 2021])

# %% [markdown]
# ### 1.8.2 Unique values in job_title

# %%
df['job_title'].unique()
# Out:
# array(['Machine Learning Engineer  in office', 'Statistician  (Remote)',
#        'Machine Learning Engineer', 'Data Analyst  in office',
#        'Statistician', 'Data Scientist  (Remote)', 'Data Analyst',
#        'Data Engineer  in office', 'Data Scientist',
#        'Machine Learning Engineer  (Remote)', 'Data Engineer',
#        'Data Engineer  (Remote)', 'Data Scientist  in office',
#        'Data Analyst  (Remote)', 'Statistician  in office'], dtype=object)

# %% [markdown]
# ###1.8.3 Unique values in job_category

# %%
df['job_category'].unique()
# Out:
# array(['Analysis', 'ML/AI', 'Data Science', 'Engineering', nan],
#       dtype=object)

# %% [markdown]
# ### 1.8.4 Unique values in salary_currency

# %%
df['salary_currency'].unique()
# Out:
# array(['EUR', 'JPY', 'INR', nan, 'us dolars', 'GBP'], dtype=object)

# %% [markdown]
# ### 1.8.5 Unique values in employee residence

# %%
df['employee_residence'].unique()
# Out:
# array(['US', 'JP', 'UK', 'DE', 'CN', 'MX', 'IN'], dtype=object)

# %% [markdown]
# USA, Japan, UK, Germany (DE), China (CN), Mexico (MX), India (IN)

# %% [markdown]
# ### 1.8.6 Unique values in experience leve

# %%
df['experience_level'].unique()
# Out:
# array(['MI', 'EX', 'SE', nan, 'EN'], dtype=object)

# %% [markdown]
# MI (mid level), Senior Level (SE), Entry Level (EN),

# %% [markdown]
# ### 1.8.7 Unique values in employement type

# %%
df['employment_type'].unique()
# Out:
# array(['CT', 'FL', 'FT', 'PT'], dtype=object)

# %% [markdown]
# Full time (FT), Part time (PT), Contract (CT),

# %% [markdown]
# ### 1.8.8. Unique values in work_setting

# %%
df['work_setting'].unique()
# Out:
# array(['Remote', 'Hybrid', 'In-person'], dtype=object)

# %% [markdown]
# ###1.8.9 Unique values in company location

# %%
df['company_location'].unique()
# Out:
# array(['DE', 'IN', 'CN', 'MX', 'UK', 'JP', 'US'], dtype=object)

# %% [markdown]
# ### 1.8.10 Unique values in company size

# %%
df['company_size'].unique()
# Out:
# array(['L', 'M', 'S', nan], dtype=object)

# %% [markdown]
# # 1.9 Identify and count the number of duplicate rows in the data frame

# %% [markdown]
# The df.duplicated().sum() function in Pandas is used to count the number of duplicate rows in a DataFrame. This is useful for identifying and understanding duplicate entries, which may need to be addressed through data cleaning or preprocessing.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #1.10 Histogram of numerical type data type

# %%
df.hist(figsize=(7,8))
plt.show()

# %% [markdown]
# salary's are shown in negative

# %% [markdown]
# #1.11 Outlier checking

# %% [markdown]
# Outliers are data points that differ significantly from the majority of the data in a dataset. They can indicate variability in the data, errors, or exceptional cases. Identifying and handling outliers is crucial for data analysis and machine learning because outliers can skew the results and affect the performance of models.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
plt.figure(figsize=(7, 4))
plt.subplot(1,2,1)
sns.boxplot(x=df['salary'])
plt.title('Box Plot of Salary')
plt.xlabel('Salary')

plt.subplot(1,2,2)
sns.boxplot(x=df['salary_in_usd'])
plt.title('Box Plot of Salary in usd')
plt.xlabel('Salary')
plt.show()

# %% [markdown]
# again salary is shown negative, probably the reason for outlier

# %% [markdown]
# Convert values in to absolute values

# %%
df['salary']=abs(df['salary'])
df['salary']
# Out:
# 0       186597
# 1       110630
# 2        61280
# 3       154130
# 4       172312
#          ...
# 4995    179769
# 4996    184642
# 4997    135319
# 4998     58037
# 4999    143565
# Name: salary, Length: 5000, dtype: int64

# %%
df.hist(figsize=(7,8))
plt.show()

# %%
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# salary issue is fixed. Outliers are removed

# %% [markdown]
# # Barplot of every column

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
df['work_year'].value_counts().plot(kind='bar')
plt.subplot(1,3,2)
df['job_title'].value_counts().plot(kind='bar')
plt.subplot(1,3,3)
df['job_category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_category'>

# %% [markdown]
# - Number of data is slightly larger in 2020
# - More job title is 'Data Engineer in office'. Least is 'Machine Learning Engineer'
# - In the given data, job category is more for 'Data Science' and least for 'Engineering'

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
df['salary_currency'].value_counts().plot(kind='bar')
plt.subplot(1,3,2)
plt.scatter(df.index, df['salary'])
plt.xlabel('Index')
plt.ylabel('Salary')
plt.title('Salary')
plt.subplot(1,3,3)
plt.scatter(df.index, df['salary_in_usd'])
plt.xlabel('Index')
plt.ylabel('Salary')
plt.title('Salary in usd')
plt.show()

# %% [markdown]
# - Most salary is paid in Eur, least in GBP

# %%
df.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
df['employee_residence'].value_counts().plot(kind='bar')
plt.subplot(1,3,2)
df['experience_level'].value_counts().plot(kind='bar')
plt.subplot(1,3,3)
df['employment_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='employment_type'>

# %% [markdown]
# - Most employees reside in Japan and least in UK
# - Most employees are SE and least are MI
# - Most employees are PT and least are CT

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
df['work_setting'].value_counts().plot(kind='bar')
plt.subplot(1,3,2)
df['company_location'].value_counts().plot(kind='bar')
plt.subplot(1,3,3)
df['company_size'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='company_size'>

# %% [markdown]
# ## Correlation between 'salary' and 'salary in usd'

# %%
correlation = df['salary'].corr(df['salary_in_usd'])
print(f"The correlation between salary and salary_in_usd is: {correlation}")
# Out:
# The correlation between salary and salary_in_usd is: 0.012067227605794395

# %% [markdown]
# ## There is no correlation between Salary and Salary in usd (better to remove one and take other as target column)

# %% [markdown]
# #1.12 Univariate analysis

# %% [markdown]
# Univariate analysis is the simplest form of data analysis technique in data science. It involves analyzing a single variable to understand its underlying patterns and properties. The term "univariate" indicates that only one variable is analyzed at a time, without considering relationships or dependencies with other variables.

# %%
columns=df.columns
columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# ## Univaraite analysis of numerical columns (Salary, Salary in usd, work year)

# %% [markdown]
# ### Histogram

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Assuming 'salary', 'salary_in_usd', and 'work_year' are your numerical columns
sns.histplot(df['salary'], ax=axes[0])
axes[0].set_title('Salary Histogram')

sns.histplot(df['salary_in_usd'], ax=axes[1])
axes[1].set_title('Salary in USD Histogram')

sns.histplot(df['work_year'], ax=axes[2])
axes[2].set_title('Work Year Histogram')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Overlapped histogram of salary and salary in usd

# %%
# Assuming 'df' is your DataFrame and it's already loaded
plt.figure(figsize=(8, 6))
plt.hist(df['salary'], bins=30, alpha=0.5, label='Salary')
plt.hist(df['salary_in_usd'], bins=30, alpha=0.5, label='Salary in USD')
plt.xlabel('Salary/Salary in USD')
plt.ylabel('Frequency')
plt.title('Overlapping Histogram of Salary and Salary in USD')
plt.legend()
plt.show()

# %% [markdown]
# Salary counts are different against each salary

# %% [markdown]
# ### Box plot

# %%
numerical=['salary','salary_in_usd','work_year']
sns.boxplot(data=df[numerical])
# Out:
# <Axes: >

# %% [markdown]
# Salary and salary in usd are nearly identical

# %% [markdown]
# ### Density plot

# %%
numerical = ['salary', 'salary_in_usd', 'work_year']

plt.figure(figsize=(15, 5))
for i, col in enumerate(numerical):
    plt.subplot(1, 3, i + 1)
    sns.kdeplot(df[col])
    plt.title(f'Density Plot of {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# Nearly similar density plot for salary and salary in usd

# %% [markdown]
# ## Univariate analysis of categorical columns

# %%
categorical_features = ['job_title', 'job_category', 'salary_currency',
                        'employee_residence', 'experience_level',
                        'employment_type', 'work_setting', 'company_location',
                        'company_size']

fig, axes = plt.subplots(3, 3, figsize=(15, 15))
for i, feature in enumerate(categorical_features):
  row = i // 3
  col = i % 3
  sns.countplot(x=feature, data=df, ax=axes[row, col])
  axes[row, col].set_title(f'Distribution of {feature}')
  axes[row, col].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# There is no noticable difference in count in each plot against its different x variables

# %% [markdown]
# #1.13 Bivariate analysis with 'salary' as target variable

# %% [markdown]
# Bivariate analysis is the statistical analysis of two variables to explore the relationship between them. It extends univariate analysis by examining how one variable correlates, depends, or varies with another. This method is fundamental in understanding interactions within datasets and is widely used in data science for insights and decision-making.

# %%
df.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# ## 1. Bivariate plot of salary agains salary in usd

# %% [markdown]
# ###Scatter plot

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['salary'], df['salary_in_usd'])
plt.xlabel('Salary')
plt.ylabel('Salary in USD')
plt.title('Scatter Plot of Salary vs. Salary in USD')
plt.show()

# %% [markdown]
# Appears like no relation at all. When salary was 25000 salary  in usd was as high as 200000. Similarly when salary in usd was 25000, salary was 200000. No relationship at all.

# %% [markdown]
# ## Let's take Salary in usd as target variable

# %%
df.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# ## 2. Bivariate analysis of job title vs salary in usd

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Data Engineer  in office                372
# Data Engineer                           355
# Statistician                            354
# Data Scientist                          353
# Data Analyst  in office                 339
# Data Engineer  (Remote)                 338
# Data Analyst  (Remote)                  336
# Machine Learning Engineer  in office    331
# Data Scientist  in office               330
# Machine Learning Engineer  (Remote)     327
# Statistician  (Remote)                  323
# Statistician  in office                 317
# Data Scientist  (Remote)                310
# Data Analyst                            309
# Machine Learning Engineer               306
# Name: count, dtype: int64

# %% [markdown]
# ### Scatter plot

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['job_title'], df['salary_in_usd'])
plt.xlabel('Job Title')
plt.ylabel('Salary in USD')
plt.title('Job Title vs. Salary in USD')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Boxplot

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='job_title', y='salary_in_usd', data=df)
plt.xlabel('Job Title')
plt.ylabel('Salary in USD')
plt.title('Job Title vs. Salary in USD (Boxplot)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Line grap of mean, max and min of salary in usd for each job title

# %%
# Calculate the mean, max, and min salary for each job title
job_title_stats = df.groupby('job_title')['salary_in_usd'].agg(['mean', 'max', 'min'])

# Create the line plot
plt.figure(figsize=(8, 6))
plt.plot(job_title_stats.index, job_title_stats['mean'], label='Mean Salary', marker='o')
plt.plot(job_title_stats.index, job_title_stats['max'], label='Max Salary', marker='o')
plt.plot(job_title_stats.index, job_title_stats['min'], label='Min Salary', marker='o')

# Customize the plot
plt.xlabel('Job Title')
plt.ylabel('Salary in USD')
plt.title('Mean, Max, and Min Salary for Each Job Title')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# Any partiular job title does not make any difference in salary in usd. All have nearly the same salary in usd

# %% [markdown]
# ### 3. Bivariate analysis of Job category vs salary in usd

# %% [markdown]
# ### Scatter plot

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='job_category', y='salary_in_usd', data=df)
plt.xlabel('Job Category')
plt.ylabel('Salary in USD')
plt.title('Job Category vs. Salary in USD')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Boxplot

# %%
# Assuming 'df' is your DataFrame and it's already loaded

plt.figure(figsize=(8, 4))
sns.boxplot(x='job_category', y='salary_in_usd', data=df)
plt.xlabel('Job Category')
plt.ylabel('Salary in USD')
plt.title('Job Category vs. Salary in USD (Boxplot)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Again job category doesn't make any differenc in salary in usd

# %% [markdown]
# ##4. Bivariate analysis of salary currency vs salary in usd

# %% [markdown]
# ### Scatter plot

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(x='salary_currency', y='salary_in_usd', data=df)
plt.xlabel('Salary Currency')
plt.ylabel('Salary in USD')
plt.title('Salary Currency vs. Salary in USD')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Assuming 'df' is your DataFrame and it's already loaded

plt.figure(figsize=(8, 4))
sns.boxplot(x='salary_currency', y='salary_in_usd', data=df)
plt.xlabel('Salary Currency')
plt.ylabel('Salary in USD')
plt.title('Box Plot of Salary in USD vs. Salary Currency')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Bivariate analysis of employee residence vs salary in usd

# %% [markdown]
# ### Scatter plot

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(x='employee_residence', y='salary_in_usd', data=df)
plt.xlabel('Employee Residence')
plt.ylabel('Salary in USD')
plt.title('Employee Residence vs. Salary in USD')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# ###Boxplot of each employee residence vs salary in usd

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x='employee_residence', y='salary_in_usd', data=df)
plt.xlabel('Employee Residence')
plt.ylabel('Salary in USD')
plt.title('Boxplot of Employee Residence vs. Salary in USD')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###line graph of each employee residence vs mean salary in usd

# %%
# Calculate the mean salary for each employee residence
residence_stats = df.groupby('employee_residence')['salary_in_usd'].mean()

# Create the line plot
plt.figure(figsize=(8, 4))
plt.plot(residence_stats.index, residence_stats.values, marker='o')

# Customize the plot
plt.xlabel('Employee Residence')
plt.ylabel('Mean Salary in USD')
plt.title('Mean Salary in USD for Each Employee Residence')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.grid(True)  # Add grid lines
plt.show()

# %% [markdown]
# Mean salary is slightly larger in Mexico and least in usa

# %% [markdown]
# ##6. Bivariate analysis experience level vs salary in usd

# %% [markdown]
# ###scatter plot of each experience level vs salary in usd

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(x='experience_level', y='salary_in_usd', data=df)
plt.xlabel('Experience Level')
plt.ylabel('Salary in USD')
plt.title('Experience Level vs. Salary in USD')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###boxplot each experience level vs salary in usd

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x='experience_level', y='salary_in_usd', data=df)
plt.xlabel('Experience Level')
plt.ylabel('Salary in USD')
plt.title('Boxplot of Experience Level vs. Salary in USD')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Bivariate analysis of employment type vs salary in usd

# %% [markdown]
# ###scatter plot of each employment type vs salary in usd

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(x='employment_type', y='salary_in_usd', data=df)
plt.xlabel('Employment Type')
plt.ylabel('Salary in USD')
plt.title('Employment Type vs. Salary in USD')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###boxplot of each employment type vs salary in usd

# %%
# Assuming 'df' is your DataFrame and it's already loaded

plt.figure(figsize=(8, 4))
sns.boxplot(x='employment_type', y='salary_in_usd', data=df)
plt.xlabel('Employment Type')
plt.ylabel('Salary in USD')
plt.title('Boxplot of Employment Type vs. Salary in USD')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##8. Bivariate analysis of work setting vs salary in usd

# %% [markdown]
# ###scatter plot of each work setting vs salry in usd

# %%
# Assuming 'df' is your DataFrame and it's already loaded
plt.figure(figsize=(8, 4))
sns.scatterplot(x='work_setting', y='salary_in_usd', data=df)
plt.xlabel('Work Setting')
plt.ylabel('Salary in USD')
plt.title('Scatter Plot of Work Setting vs. Salary in USD')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###boxplot of each work setting vs salary in usd

# %%
# Assuming 'df' is your DataFrame and it's already loaded

plt.figure(figsize=(8, 4))
sns.boxplot(x='work_setting', y='salary_in_usd', data=df)
plt.xlabel('Work Setting')
plt.ylabel('Salary in USD')
plt.title('Boxplot of Work Setting vs. Salary in USD')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Bivariate analysis of experience level vs salary in usd

# %% [markdown]
# ###scatter plot of each experience level vs salary in usd

# %%
# Assuming 'df' is your DataFrame and it's already loaded

plt.figure(figsize=(8, 4))
sns.scatterplot(x='experience_level', y='salary_in_usd', data=df)
plt.xlabel('Experience Level')
plt.ylabel('Salary in USD')
plt.title('Scatter Plot of Experience Level vs. Salary in USD')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###boxplot of each experience level vs salary in usd

# %%
# Assuming 'df' is your DataFrame and it's already loaded

plt.figure(figsize=(8, 4))
sns.boxplot(x='experience_level', y='salary_in_usd', data=df)
plt.xlabel('Experience Level')
plt.ylabel('Salary in USD')
plt.title('Boxplot of Experience Level vs. Salary in USD')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Bivariate analysis of company size vs salary in usd

# %% [markdown]
# ###scatter plot of company size vs salary in usd

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(x='company_size', y='salary_in_usd', data=df)
plt.xlabel('Company Size')
plt.ylabel('Salary in USD')
plt.title('Scatter Plot of Company Size vs. Salary in USD')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###boxplot of company size vs salary in usd

# %%
# Assuming 'df' is your DataFrame and it's already loaded

plt.figure(figsize=(8, 4))
sns.boxplot(x='company_size', y='salary_in_usd', data=df)
plt.xlabel('Company Size')
plt.ylabel('Salary in USD')
plt.title('Boxplot of Company Size vs. Salary in USD')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #1.14 Checking for any correaltion between salary and salary in usd-Groupby analysis

# %% [markdown]
# ## Data frame Salary, Salary in usd and its ratio

# %%
#create a dataframe of salary and salary in usd for salary currency 'INR'

# Create a DataFrame with salary and salary_in_usd for 'INR' currency
inr_df = df[df['salary_currency'] == 'INR'][['salary', 'salary_in_usd']]
inr_df['ratio']=inr_df['salary']/inr_df['salary_in_usd']
inr_df
# Out:
#       salary  salary_in_usd     ratio
# 2      61280         153309  0.399716
# 11    118202          50997  2.317823
# 19     77646         194857  0.398477
# 25    174408         175450  0.994061
# 28    186453         165772  1.124756
# ...      ...            ...       ...
# 4967   96376          34902  2.761332
# 4971   45405          43967  1.032706
# 4977  125659         146327  0.858755
# 4985  140736          79483  1.770643
# 4992   37404          37426  0.999412
#
# [916 rows x 3 columns]

# %% [markdown]
# ## Dataframe of salary, salary in usd and its ratio only for salary currency INR

# %%
#create a dataframe of salary and salary in usd for salary currency 'INR', employee residence 'IN' and company location 'IN'

# Assuming 'df' is your DataFrame as defined in the provided code.

# Create a DataFrame with specified conditions
new_df = df[(df['salary_currency'] == 'INR') & (df['employee_residence'] == 'IN') & (df['company_location'] == 'IN')]

# Select only the 'salary' and 'salary_in_usd' columns
new_df = new_df[['salary', 'salary_in_usd']]

# Display the new DataFrame
new_df['salary_ratio']=new_df['salary']/new_df['salary_in_usd']
new_df
# Out:
#       salary  salary_in_usd  salary_ratio
# 56    133186          85344      1.560578
# 823    84515         132528      0.637714
# 1796   58087         108513      0.535300
# 1955  148301          56859      2.608224
# 2041   31287         184925      0.169188
# 2466  199839         167711      1.191568
# 2841  107760         186374      0.578192
# 2972  177545         101744      1.745017
# 3193  160115         179466      0.892175
# 3446  157430         168279      0.935530
# 3518  152082         166451      0.913674
# 3602  119218         140612      0.847851
# 3703  170944         131092      1.304000
# 4859  171072         199556      0.857263

# %% [markdown]
# ##Plot of salary, salary in usd and its ratio only for salary currency INR

# %%
plt.plot(new_df['salary'],marker='*')
plt.plot(new_df['salary_in_usd'],marker='o')
plt.show()

# %% [markdown]
# ##Dataframe of salary, salary in usd and its ratio only for salary currency INR, employee residence IN and company location IN

# %%
# prompt: create a dataframe of salary and salary in usd for salary currency 'INR', employee residence 'IN' and company location 'IN' for the year 2022

# Assuming 'df' is your DataFrame as defined in the provided code.

# Create a DataFrame with specified conditions for the year 2022
new_df = df[(df['salary_currency'] == 'INR') &
            (df['employee_residence'] == 'IN') &
            (df['company_location'] == 'IN') &
            (df['work_year'] == 2021)]

# Select only the 'salary' and 'salary_in_usd' columns
new_df = new_df[['salary', 'salary_in_usd']]

# Display the new DataFrame
new_df['salary_ratio']=new_df['salary']/new_df['salary_in_usd']
new_df
# Out:
#       salary  salary_in_usd  salary_ratio
# 823    84515         132528      0.637714
# 1796   58087         108513      0.535300
# 1955  148301          56859      2.608224
# 2041   31287         184925      0.169188
# 2841  107760         186374      0.578192
# 2972  177545         101744      1.745017
# 3518  152082         166451      0.913674
# 3703  170944         131092      1.304000
# 4859  171072         199556      0.857263

# %%
#correaltion between salary and salary in usd

correlation = df['salary'].corr(df['salary_in_usd'])
print(f"The correlation between salary and salary_in_usd is: {correlation}")
# Out:
# The correlation between salary and salary_in_usd is: 0.012067227605794395

# %% [markdown]
# ### No correlation between salary and salary in usd

# %% [markdown]
# #1.15 Checking how job category 'Data Science' realted to 'salary' and 'salary in usd'

# %%
# prompt: plot job category 'Data Science' vs 'salary' and 'Data Science' vs 'salary in usd' side by side plot

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame and it's already loaded
# ... (Your existing code to load and preprocess the data) ...

# Filter for 'Data Science' job category
data_science_df = df[df['job_category'] == 'Data Science']

# Create the side-by-side plots
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.scatterplot(x='job_category', y='salary', data=data_science_df)
plt.xlabel('Job Category')
plt.ylabel('Salary')
plt.title('Data Science vs. Salary')
plt.xticks(rotation=45, ha='right')

plt.subplot(1, 2, 2)
sns.scatterplot(x='job_category', y='salary_in_usd', data=data_science_df)
plt.xlabel('Job Category')
plt.ylabel('Salary (USD)')
plt.title('Data Science vs. Salary (USD)')
plt.xticks(rotation=45, ha='right')


plt.tight_layout()
plt.show()

# %% [markdown]
# Again no correlation is found

# %% [markdown]
# ---

# %% [markdown]
# # Week-2

# %% [markdown]
# ---

# %% [markdown]
# #2.1  Handling missing values

# %%
df.isna().sum()
# Out:
# work_year               0
# job_title               0
# job_category          500
# salary_currency       500
# salary                  0
# salary_in_usd           0
# employee_residence      0
# experience_level      500
# employment_type         0
# work_setting            0
# company_location        0
# company_size          500
# dtype: int64

# %%
df.sample(5)
# Out:
#       work_year                            job_title  job_category  \
# 1456       2022              Data Engineer  (Remote)  Data Science
# 467        2021  Machine Learning Engineer  (Remote)  Data Science
# 4377       2021               Statistician  (Remote)      Analysis
# 4064       2022  Machine Learning Engineer  (Remote)      Analysis
# 4548       2020            Data Scientist  in office      Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 1456             INR  183609          87943                 DE
# 467              INR  141736          66069                 JP
# 4377             JPY  189027          46411                 IN
# 4064             EUR   36829         102178                 JP
# 4548             EUR  126806         189149                 US
#
#      experience_level employment_type work_setting company_location  \
# 1456               SE              CT    In-person               DE
# ...

# %% [markdown]
# ### There are missing values in job_category, salary_currency,experience level and experience level

# %% [markdown]
# ## A dataset made of rows consisting of missing values

# %%
#create a subset of df with job_category=NaN

# Assuming 'df' is your DataFrame as defined in the provided code.
subset_df = df[df['job_category'].isna()]
subset_df
# Out:
#       work_year                            job_title job_category  \
# 8          2022                         Data Analyst          NaN
# 12         2020  Machine Learning Engineer  (Remote)          NaN
# 23         2021                         Statistician          NaN
# 26         2020                       Data Scientist          NaN
# 29         2022                        Data Engineer          NaN
# ...         ...                                  ...          ...
# 4923       2020                       Data Scientist          NaN
# 4966       2022                         Statistician          NaN
# 4975       2022            Machine Learning Engineer          NaN
# 4995       2020  Machine Learning Engineer  (Remote)          NaN
# 4996       2021  Machine Learning Engineer  (Remote)          NaN
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# 8                NaN   44388         171043                 UK
# ...

# %%
subset_df.shape
# Out:
# (500, 12)

# %% [markdown]
# ### Number of missing values in each job category

# %%
subset_df['job_title'].value_counts()
# Out:
# job_title
# Statistician                            42
# Machine Learning Engineer  in office    40
# Data Scientist                          38
# Machine Learning Engineer               38
# Data Engineer  (Remote)                 38
# Machine Learning Engineer  (Remote)     37
# Data Scientist  in office               37
# Data Analyst  (Remote)                  33
# Data Engineer                           32
# Data Engineer  in office                30
# Statistician  (Remote)                  28
# Statistician  in office                 28
# Data Analyst                            27
# Data Analyst  in office                 26
# Data Scientist  (Remote)                26
# Name: count, dtype: int64

# %% [markdown]
# ## Number of missing values in Employee Residence

# %%
subset_df['employee_residence'].value_counts()
# Out:
# employee_residence
# JP    86
# MX    78
# IN    78
# US    76
# DE    65
# UK    59
# CN    58
# Name: count, dtype: int64

# %% [markdown]
# ## Number of missing values in Employment type

# %%
subset_df['employment_type'].value_counts()
# Out:
# employment_type
# PT    139
# FT    129
# FL    116
# CT    116
# Name: count, dtype: int64

# %%
subset_df['work_setting'].value_counts()
# Out:
# work_setting
# In-person    171
# Remote       170
# Hybrid       159
# Name: count, dtype: int64

# %%
subset_df['company_location'].value_counts()
# Out:
# company_location
# MX    83
# IN    78
# DE    73
# JP    72
# US    69
# CN    64
# UK    61
# Name: count, dtype: int64

# %%
# plot 'job_title' vs salary in usd

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='salary_in_usd', y='job_title', data=df)
plt.xlabel('Salary in USD')
plt.ylabel('Job Title')
plt.title('Job Title vs. Salary in USD')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# plot 'job_title' vs salary in usd

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='salary_in_usd', y='job_title', data=subset_df)
plt.xlabel('Salary in USD')
plt.ylabel('Job Title')
plt.title('Job Title vs. Salary in USD in the missing value dataset')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# prompt: plot 'job_title' vs salary

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='salary_in_usd', y='job_title', data=subset_df)
plt.xlabel('Salary in USD')
plt.ylabel('Job Title')
plt.title('Job Title vs. Salary in USD in the missing value dataset')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###The plot shows no relation between salary and salary in usd

# %%
df.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# All the missing values are in the same rows

# %% [markdown]
# ##scatter plot work year, job title, employee residence, work type, work setting, company location agains salary in usd of subset_df

# %%
# Assuming 'subset_df' is already defined as in your provided code.

plt.figure(figsize=(15, 10))

plt.subplot(3, 2, 1)
sns.scatterplot(x='work_year', y='salary_in_usd', data=subset_df)
plt.xlabel('Work Year')
plt.ylabel('Salary in USD')
plt.title('Work Year vs. Salary in USD')

plt.subplot(3, 2, 2)
sns.scatterplot(x='job_title', y='salary_in_usd', data=subset_df)
plt.xlabel('Job Title')
plt.ylabel('Salary in USD')
plt.title('Job Title vs. Salary in USD')
plt.xticks(rotation=90)

plt.subplot(3, 2, 3)
sns.scatterplot(x='employee_residence', y='salary_in_usd', data=subset_df)
plt.xlabel('Employee Residence')
plt.ylabel('Salary in USD')
plt.title('Employee Residence vs. Salary in USD')
plt.xticks(rotation=90)

plt.subplot(3, 2, 4)
sns.scatterplot(x='employment_type', y='salary_in_usd', data=subset_df)
plt.xlabel('Work Type')
plt.ylabel('Salary in USD')
plt.title('Work Type vs. Salary in USD')
plt.xticks(rotation=45)

plt.subplot(3, 2, 5)
sns.scatterplot(x='work_setting', y='salary_in_usd', data=subset_df)
plt.xlabel('Work Setting')
plt.ylabel('Salary in USD')
plt.title('Work Setting vs. Salary in USD')

plt.subplot(3, 2, 6)
sns.scatterplot(x='company_location', y='salary_in_usd', data=subset_df)
plt.xlabel('Company Location')
plt.ylabel('Salary in USD')
plt.title('Company Location vs. Salary in USD')
plt.xticks(rotation=90)


plt.tight_layout()
plt.show()

# %% [markdown]
# ##2.1.1. Filling missing values randomly to keep the distribution same

# %%
df.isna().sum()
# Out:
# work_year               0
# job_title               0
# job_category          500
# salary_currency       500
# salary                  0
# salary_in_usd           0
# employee_residence      0
# experience_level      500
# employment_type         0
# work_setting            0
# company_location        0
# company_size          500
# dtype: int64

# %% [markdown]
# ### Since job_category, experience level and company size does not make any differenec in salary in usd we can fill missing values eually so that distribution remains same. We can fill using random method

# %%
dff=df.copy()

# %% [markdown]
# ##fill missing values job_category, experience level and company size randomly

# %%
# Fill missing values in 'job_category', 'experience_level', and 'company_size' randomly
for col in ['job_category', 'experience_level', 'company_size']:
    unique_values = dff[col].dropna().unique()
    dff[col] = dff[col].fillna(pd.Series(np.random.choice(unique_values, size=len(dff))))

# %%
dff.isna().sum()
# Out:
# work_year               0
# job_title               0
# job_category            0
# salary_currency       500
# salary                  0
# salary_in_usd           0
# employee_residence      0
# experience_level        0
# employment_type         0
# work_setting            0
# company_location        0
# company_size            0
# dtype: int64

# %%
# scatter plot of employee residence and salary currency against salary in usd in same graph

plt.figure(figsize=(10, 6))
sns.scatterplot(x='salary_in_usd', y='employee_residence', hue='salary_currency', data=df)
plt.xlabel('Salary in USD')
plt.ylabel('Employee Residence')
plt.title('Employee Residence and Salary Currency vs. Salary in USD')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###scatter plot of employee residence vs salary in usd for subset_df

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(x='employee_residence', y='salary_in_usd', data=subset_df)
plt.xlabel('Employee Residence')
plt.ylabel('Salary in USD')
plt.title('Employee Residence vs. Salary in USD (Subset)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###Fill missing values in salary currency with employee residence countries currency that is if employee residence is UK, fill it with GBP, if US fill it with us dolars, if DE, fill it with EUR, if IN fill it with INR,  if Jp fill it with JPY. If employee residence is MX or CN fill it randomly with randomly with GBP, US, EUR, JPY, INR

# %%
# Fill missing 'salary_currency' based on 'employee_residence'
def fill_salary_currency(row):
    if pd.isnull(row['salary_currency']):
        if row['employee_residence'] == 'UK':
            return 'GBP'
        elif row['employee_residence'] == 'US':
            return 'us dolars'
        elif row['employee_residence'] == 'DE':
            return 'EUR'
        elif row['employee_residence'] == 'IN':
            return 'INR'
        elif row['employee_residence'] == 'JP':
            return 'JPY'
        elif row['employee_residence'] in ['MX', 'CN']:
            return np.random.choice(['GBP', 'us dolars', 'EUR', 'JPY', 'INR'])
        else:
            return np.nan  # Or another strategy for other countries
    return row['salary_currency']

dff['salary_currency'] = dff.apply(fill_salary_currency, axis=1)

# %% [markdown]
# ##histogram of job category, salary currency, experience level and company size in df and dff side by side (before and after filling null values)

# %%
# prompt: histogram of job category, salary currency, experience level and company size in df and dff side by side

import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 4, figsize=(12, 8))

# df histograms
sns.histplot(df['job_category'], ax=axes[0, 0])
axes[0, 0].set_title('Job Category (df)')
sns.histplot(df['salary_currency'], ax=axes[0, 1])
axes[0, 1].set_title('Salary Currency (df)')
sns.histplot(df['experience_level'], ax=axes[0, 2])
axes[0, 2].set_title('Experience Level (df)')
sns.histplot(df['company_size'], ax=axes[0, 3])
axes[0, 3].set_title('Company Size (df)')


# dff histograms
sns.histplot(dff['job_category'], ax=axes[1, 0])
axes[1, 0].set_title('Job Category (dff)')
sns.histplot(dff['salary_currency'], ax=axes[1, 1])
axes[1, 1].set_title('Salary Currency (dff)')
sns.histplot(dff['experience_level'], ax=axes[1, 2])
axes[1, 2].set_title('Experience Level (dff)')
sns.histplot(dff['company_size'], ax=axes[1, 3])
axes[1, 3].set_title('Company Size (dff)')

plt.tight_layout()
plt.show()

# %%
dff.isna().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# #2.2 Outlier Handling

# %% [markdown]
# There are no outliers

# %% [markdown]
# ---

# %% [markdown]
# ## dff is the data set with missing values filled

# %%
dff.sample(10)
# Out:
#       work_year                 job_title  job_category salary_currency  \
# 2609       2021            Data Scientist   Engineering       us dolars
# 139        2020   Statistician  in office  Data Science             EUR
# 3219       2021  Data Scientist  (Remote)      Analysis       us dolars
# 3011       2020  Data Scientist  (Remote)      Analysis       us dolars
# 2490       2020              Data Analyst  Data Science       us dolars
# 3081       2021   Data Analyst  in office      Analysis             JPY
# 4306       2020   Statistician  in office   Engineering             GBP
# 742        2022   Statistician  in office  Data Science       us dolars
# 2287       2020              Data Analyst         ML/AI             INR
# 709        2022            Data Scientist      Analysis             EUR
#
#       salary  salary_in_usd employee_residence experience_level  \
# 2609  135737          68148                 CN               EN
# ...

# %%
df.shape
# Out:
# (5000, 12)

# %%
dff.shape
# Out:
# (5000, 12)

# %%
df.columns
# Out:
# Index(['work_year', 'job_title', 'job_category', 'salary_currency', 'salary',
#        'salary_in_usd', 'employee_residence', 'experience_level',
#        'employment_type', 'work_setting', 'company_location', 'company_size'],
#       dtype='object')

# %% [markdown]
# ##EDA shows that work_year, salary currency, salary, employee residence, company location have no influence at all in target variable 'salary in usd'. So let's remove it from the data. Others also don't have any correlation, but let's keept it.<br>
#
# Dropped columns
# 1. work_year
# 2. salary_currency
# 3. salary
# 4. employee_residence
# 5. company_location

# %% [markdown]
# ## Removing 'salary' from data frame and take 'salary in usd' as target column

# %%
dfa=dff.copy()

# %%
dfa = dfa.drop(['work_year', 'salary_currency','salary','employee_residence','company_location'], axis=1)

# %%
dfa.shape
# Out:
# (5000, 7)

# %%
dfa.sample(5)
# Out:
#                       job_title job_category  salary_in_usd experience_level  \
# 1315     Data Analyst  (Remote)     Analysis         153086               EN
# 2000    Data Analyst  in office        ML/AI         167776               EX
# 643   Data Scientist  in office     Analysis          78917               EN
# 4209    Data Engineer  (Remote)        ML/AI          48134               MI
# 1752  Data Scientist  in office     Analysis         163745               EN
#
#      employment_type work_setting company_size
# 1315              CT    In-person            M
# 2000              FL    In-person            S
# 643               PT       Hybrid            M
# 4209              PT    In-person            L
# 1752              CT       Remote            M

# %% [markdown]
# #2.3 Encoding

# %%
#encode dfa using onehotencoder

# Create a OneHotEncoder object
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

# Fit the encoder on your categorical features
# Assuming 'job_title', 'experience_level', 'employment_type', 'job_category', 'work_setting', and 'company_size' are your categorical features.
#categorical_cols = ['job_title', 'experience_level', 'employment_type', 'job_category', 'work_setting', 'company_size']
#encoded_features = encoder.fit_transform(dfa[categorical_cols]).toarray()
#encoded_df = pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out(categorical_cols))


encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoded_columns = encoder.fit_transform(df[['job_title', 'experience_level', 'employment_type', 'job_category', 'work_setting', 'company_size']])
encoded_df = pd.DataFrame(encoded_columns, columns=encoder.get_feature_names_out())


# Concatenate the encoded features with the numerical features
# Assuming 'salary_in_usd' is your target variable.
numerical_cols = ['salary_in_usd']
dfa_encoded = pd.concat([dfa[numerical_cols], encoded_df], axis=1)

dfa_encoded.sample(5)
# Out:
#       salary_in_usd  job_title_Data Analyst  job_title_Data Analyst  (Remote)  \
# 3861          45546                     0.0                               0.0
# 4268         178777                     0.0                               0.0
# 3993         167245                     0.0                               0.0
# 576          175995                     0.0                               0.0
# 1522         170005                     0.0                               0.0
#
#       job_title_Data Analyst  in office  job_title_Data Engineer  \
# 3861                                0.0                      0.0
# 4268                                1.0                      0.0
# 3993                                0.0                      0.0
# 576                                 0.0                      0.0
# 1522                                0.0                      0.0
#
#       job_title_Data Engineer  (Remote)  job_title_Data Engineer  in office  \
# ...

# %%
dfa_encoded.shape
# Out:
# (5000, 37)

# %% [markdown]
# # Pickling encoder

# %%
import pickle
#convert encoder into pickle file
with open('encoder.pkl', 'wb') as f:
    pickle.dump(encoder, f)

# %% [markdown]
# # Spliting in to independent and target variable

# %%
x=dfa_encoded.drop('salary_in_usd',axis=1)
y=dfa_encoded['salary_in_usd']

# %%
x.sample(3)
# Out:
#       job_title_Data Analyst  job_title_Data Analyst  (Remote)  \
# 1446                     0.0                               0.0
# 4351                     0.0                               0.0
# 4690                     0.0                               0.0
#
#       job_title_Data Analyst  in office  job_title_Data Engineer  \
# 1446                                0.0                      1.0
# 4351                                0.0                      0.0
# 4690                                1.0                      0.0
#
#       job_title_Data Engineer  (Remote)  job_title_Data Engineer  in office  \
# 1446                                0.0                                 0.0
# 4351                                1.0                                 0.0
# 4690                                0.0                                 0.0
#
#       job_title_Data Scientist  job_title_Data Scientist  (Remote)  \
# 1446                       0.0                                 0.0
# ...

# %%
y.sample(3)
# Out:
# 299     164495
# 527      31237
# 3842     43767
# Name: salary_in_usd, dtype: int64

# %% [markdown]
# #Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (4000, 36)

# %%
x_test.shape
# Out:
# (1000, 36)

# %% [markdown]
# #2.4 Data Modelling and Evaluation

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# #Model-1: Linear Regression

# %%
lr=LinearRegression()
model=lr.fit(x_train,y_train)

# %%
y_pred=model.predict(x_test)

# %%
mse=mean_squared_error(y_test,model.predict(x_test))
mse
# Out:
# 1.1783432739270401e+36

# %%
r2_value=r2_score(y_test,y_pred)
r2_value
# Out:
# -5.033194627274332e+26

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")

# Optionally, create a comparison DataFrame
comparison_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(comparison_df.head(20)) # Print the first 20 rows for comparison
# Out:
# Mean Squared Error: 1.1783432739270401e+36
# R-squared: -5.033194627274332e+26
#       Actual     Predicted
# 1501  125675 -1.535150e+18
# 2586   63435 -1.535150e+18
# 2653   33864 -1.535150e+18
# 1055   89867 -1.535150e+18
# 705   147253 -1.535150e+18
# 106   193277 -1.535150e+18
# 589    77838 -1.535150e+18
# 2468   94546 -1.535150e+18
# 2413  114259 -1.535150e+18
# 1600   52623 -1.535150e+18
# 2464   86714 -1.535150e+18
# 228    36508 -1.535150e+18
# 915    33567 -1.535150e+18
# 794   152078 -1.535150e+18
# 3021  104229 -1.535150e+18
# 3543  132657 -1.535150e+18
# 1073  120037 -1.535150e+18
# 3351  138343 -1.535150e+18
# 1744  102940 -1.535150e+18
# 1084  145855 -1.535150e+18

# %% [markdown]
# #Model-2: Decision Tree Regressior

# %%
dtr=DecisionTreeRegressor()
model2=dtr.fit(x_train,y_train)

# %%
y_pred2=model2.predict(x_test)

# %%
mse=mean_squared_error(y_test,model.predict(x_test))
mse
# Out:
# 1.1783432739270401e+36

# %%
r2_value=r2_score(y_test,y_pred2)
r2_value
# Out:
# -0.8835229819818622

# %%
# Assuming y_pred contains the predicted values and y_test contains the actual values
# Calculate metrics
mse = mean_squared_error(y_test, y_pred2)
r2 = r2_score(y_test, y_pred2)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")

# Optionally, create a comparison DataFrame
comparison_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred2})
print(comparison_df.head(20)) # Print the first 20 rows for comparison
# Out:
# Mean Squared Error: 4409598279.944201
# R-squared: -0.8835229819818622
#       Actual  Predicted
# 1501  125675    32482.0
# 2586   63435    35060.0
# 2653   33864   115925.0
# 1055   89867    38752.0
# 705   147253   132255.0
# 106   193277   108631.0
# 589    77838    46010.0
# 2468   94546    58735.0
# 2413  114259   180822.0
# 1600   52623   118545.0
# 2464   86714    38752.0
# 228    36508   181785.0
# 915    33567    57944.0
# 794   152078    95152.0
# 3021  104229   162996.0
# 3543  132657   100272.0
# 1073  120037   100942.0
# 3351  138343   185062.0
# 1744  102940   183959.0
# 1084  145855   114414.5

# %% [markdown]
# #Model-3: Random Forest Regressor

# %%
rfr=RandomForestRegressor()
model3=rfr.fit(x_train,y_train)

# %%
y_pred3=model3.predict(x_test)

# %%
mse=mean_squared_error(y_test,model.predict(x_test))
mse
# Out:
# 1.1783432739270401e+36

# %%
r2_value=r2_score(y_test,y_pred3)
r2_value
# Out:
# -0.11115549412010184

# %%
# Assuming y_pred contains the predicted values and y_test contains the actual values
# Calculate metrics
mse = mean_squared_error(y_test, y_pred3)
r2 = r2_score(y_test, y_pred3)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")

# Optionally, create a comparison DataFrame
comparison_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred3})
print(comparison_df.head(20)) # Print the first 20 rows for comparison
# Out:
# Mean Squared Error: 2601374871.7135286
# R-squared: -0.11115549412010184
#       Actual      Predicted
# 1501  125675  109021.355333
# 2586   63435  113294.246167
# 2653   33864  117601.455333
# 1055   89867  106622.678333
# 705   147253  105407.846365
# 106   193277  102092.301889
# 589    77838  104901.618750
# 2468   94546   95033.033833
# 2413  114259  118859.067500
# 1600   52623  113025.130000
# 2464   86714  118128.046000
# 228    36508  136179.883667
# 915    33567   99316.565333
# 794   152078   80115.860833
# 3021  104229  102321.032500
# 3543  132657  120840.697167
# 1073  120037  117192.380167
# 3351  138343  121720.709667
# 1744  102940  133348.296929
# 1084  145855  124348.840667

# %% [markdown]
# #Model-4: Lasso Regressor

# %%
from sklearn.linear_model import Lasso

# %%
model4 = Lasso(alpha=0.1)  # You can adjust the alpha parameter
model4.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.943e+10, tolerance: 9.716e+08
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.1)

# %%
y_pred4 = model4.predict(x_test)

# %%
mse=mean_squared_error(y_test,model.predict(x_test))
mse
# Out:
# 1.1783432739270401e+36

# %%
r2_value=r2_score(y_test,y_pred4)
r2_value
# Out:
# -0.004874043529485839

# %% [markdown]
# #Model-5: SVR Regressor

# %%
from sklearn.svm import SVR

# %%
model5 = SVR(kernel='linear')

# %%
model5.fit(x_train, y_train)
# Out:
# SVR(kernel='linear')

# %%
y_pred5 = model5.predict(x_test)

# %%
mse_svr = mean_squared_error(y_test, y_pred5)
r2_svr = r2_score(y_test, y_pred5)

print(f"SVR - Mean Squared Error: {mse_svr}")
print(f"SVR - R-squared: {r2_svr}")
# Out:
# SVR - Mean Squared Error: 2343929516.576924
# SVR - R-squared: -0.0011898663644565044

# %%
# prompt: apply svr regression

from sklearn.svm import SVR

# Assuming x_train, x_test, y_train, y_test are already defined from the previous code

# Initialize the SVR model
svr_model = SVR(kernel='linear') # You can experiment with different kernels (e.g., 'rbf', 'poly')

# Train the model
svr_model.fit(x_train, y_train)

# Make predictions
y_pred_svr = svr_model.predict(x_test)

# Evaluate the model
mse_svr = mean_squared_error(y_test, y_pred_svr)
r2_svr = r2_score(y_test, y_pred_svr)

print(f"SVR - Mean Squared Error: {mse_svr}")
print(f"SVR - R-squared: {r2_svr}")
# Out:
# SVR - Mean Squared Error: 2343929516.576924
# SVR - R-squared: -0.0011898663644565044

# %% [markdown]
# ## Model-6: Gradient boost

# %%
# prompt: apply gradient boost regression

from sklearn.ensemble import GradientBoostingRegressor

# Initialize the Gradient Boosting Regressor model
gbr_model = GradientBoostingRegressor(random_state=42) # You can adjust hyperparameters as needed

# Train the model
gbr_model.fit(x_train, y_train)

# Make predictions
y_pred_gbr = gbr_model.predict(x_test)

# Evaluate the model
mse_gbr = mean_squared_error(y_test, y_pred_gbr)
r2_gbr = r2_score(y_test, y_pred_gbr)

print(f"Gradient Boosting Regressor - Mean Squared Error: {mse_gbr}")
print(f"Gradient Boosting Regressor - R-squared: {r2_gbr}")
# Out:
# Gradient Boosting Regressor - Mean Squared Error: 2373654437.7948785
# Gradient Boosting Regressor - R-squared: -0.013886617564279335

# %% [markdown]
# #3.1 Model Evaluation

# %% [markdown]
# # 3.2 Model Deployment

# %% [markdown]
# #Flask

# %% [markdown]
# Steps:
# 1. Create a folder any where, lets create a folder 'app'
# 2. Open the folder, in the address bar, type 'cmd'
# 3. Command prompt window will open, type 'code .'
# 4. VS code will open
# 5. Open a file, name it as model.py
# 6. Copy, past given below 'model.py' code in it
# 7. Open another file, name it as 'app.py'
# 8. Copy, past below given 'app.py' code in it
# 9. Create a folder 'templates'
# 10. Open a file 'first.html' and copy paste below given html code
# 11. Create a folder static, inside create two folder, 'img' and 'css'
# 12. place an image file 'download' in 'img' folder and paste 'css' code in 'css folder'
# 13. Run model file by typing, 'python model.py' in terminal, it will create 'encoder.pkl' and 'model.pkl'
# 14. Run app file by typing, 'python app.py'

# %% [markdown]
# ## model.py

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import train_test_split
from sklearn import linear_model

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

file_name="dsa_job.csv"

df=pd.read_csv(file_name)

df['salary']=abs(df['salary'])
dff=df.copy()

# Fill missing values in 'job_category', 'experience_level', and 'company_size' randomly
for col in ['job_category', 'experience_level', 'company_size']:
    unique_values = dff[col].dropna().unique()
    dff[col] = dff[col].fillna(pd.Series(np.random.choice(unique_values, size=len(dff))))


# Fill missing 'salary_currency' based on 'employee_residence'
def fill_salary_currency(row):
    if pd.isnull(row['salary_currency']):
        if row['employee_residence'] == 'UK':
            return 'GBP'
        elif row['employee_residence'] == 'US':
            return 'us dolars'
        elif row['employee_residence'] == 'DE':
            return 'EUR'
        elif row['employee_residence'] == 'IN':
            return 'INR'
        elif row['employee_residence'] == 'JP':
            return 'JPY'
        elif row['employee_residence'] in ['MX', 'CN']:
            return np.random.choice(['GBP', 'us dolars', 'EUR', 'JPY', 'INR'])
        else:
            return np.nan  # Or another strategy for other countries
    return row['salary_currency']

dff['salary_currency'] = dff.apply(fill_salary_currency, axis=1)


dfa=dff.copy()

dfa = dfa.drop(['work_year', 'salary_currency','salary','employee_residence','company_location'], axis=1)

#encode dfa using onehotencoder
# Create a OneHotEncoder object
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
encoded_columns = encoder.fit_transform(df[['job_title', 'experience_level', 'employment_type', 'job_category', 'work_setting', 'company_size']])
encoded_df = pd.DataFrame(encoded_columns, columns=encoder.get_feature_names_out())

# Concatenate the encoded features with the numerical features
# Assuming 'salary_in_usd' is your target variable.
numerical_cols = ['salary_in_usd']
dfa_encoded = pd.concat([dfa[numerical_cols], encoded_df], axis=1)

x=dfa_encoded.drop('salary_in_usd',axis=1)
y=dfa_encoded['salary_in_usd']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)


import pickle
with open('model.pkl','wb') as model_file:
  pickle.dump(rfr,model_file)

#convert encoder into pickle file
with open('encoder.pkl', 'wb') as f:
    pickle.dump(encoder, f)

# %% [markdown]
# ##app.py

# %%
import pandas as pd
from flask import Flask,render_template,request
import pickle
import numpy as np



app = Flask(__name__)

file_name="dsa_job.csv"

df=pd.read_csv(file_name)

rf_model = pickle.load(open('model.pkl', 'rb'))
encoder = pickle.load(open('encoder.pkl', 'rb'))

job_title_values=df['job_title'].unique()
job_category_values=df['job_category'].unique()
experience_level_values=df['experience_level'].unique()
employment_type_values=df['employment_type'].unique()
work_setting_values=df['work_setting'].unique()
company_size_values=df['company_size'].unique()

@app.route('/')
def home():
    return render_template('first.html',job_title_values=job_title_values,job_category_values=job_category_values,
                           experience_level_values=experience_level_values,employment_type_values=employment_type_values,
                           work_setting_values=work_setting_values,company_size_values=company_size_values)

@app.route('/predict',methods=['POST'])
def predict():
    #Categorical
    job_title = request.form['job_title']
    job_category = request.form['job_category']
    experience_level = request.form['experience_level']
    employment_type = request.form['employment_type']
    work_setting = request.form['work_setting']
    company_size = request.form['company_size']

    encoded_df=pd.DataFrame(encoder.transform([[job_title,job_category,experience_level,employment_type,work_setting,company_size]]), columns=encoder.get_feature_names_out())

    #input_features = np.array([[volatile_acidity,citric_acid,residual_sugar,chlorides,total_sulfur_dioxide,density,pH,sulphates,alcohol]])
    pred = rf_model.predict(encoded_df)

    target = pred[0]
    #species = wine.target_names[target]
    return render_template('first.html',pred_result = target)

if __name__=='__main__':
    app.run(debug=True)

# %% [markdown]
# ##first.html

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Data Science Job Salary Prediction using ML_by Prince Alex</title>
    <link rel='stylesheet' type='text/css' href="../static/css/style.css">
</head>
<body>
    <h1>Data Science Job Salary Prediction using ML_by Prince Alex</h1>
    <p><img align='right' src="../static/img/download.jpg" alt='df'>
    <form action="/predict" method="post">
        <label>job_title : </label>
        <select id="job_title" name="job_title" required>
            <!-- Dynamically populate Location options -->
            {% for job_title in job_title_values %}
                <option value="{{ job_title }}">{{ job_title }}</option>
            {% endfor %}
        </select>

        <label>job_category : </label>
        <select id="job_category" name="job_category" required>
            <!-- Dynamically populate Location options -->
            {% for job_category in job_category_values %}
                <option value="{{ job_category }}">{{ job_category }}</option>
            {% endfor %}
        </select>

        <label>experience_level : </label>
        <select id="experience_level" name="experience_level" required>
            <!-- Dynamically populate Location options -->
            {% for experience_level in experience_level_values %}
                <option value="{{ experience_level }}">{{ experience_level }}</option>
            {% endfor %}
        </select>

        <label>employment_type : </label>
        <select id="employment_type" name="employment_type" required>
            <!-- Dynamically populate Location options -->
            {% for employment_type in employment_type_values %}
                <option value="{{ employment_type }}">{{ employment_type }}</option>
            {% endfor %}
        </select>

        <label>work_setting : </label>
        <select id="work_setting" name="work_setting" required>
            <!-- Dynamically populate Location options -->
            {% for work_setting in work_setting_values %}
                <option value="{{ work_setting }}">{{ work_setting }}</option>
            {% endfor %}
        </select>

        <label>company_size : </label>
        <select id="company_size" name="company_size" required>
            <!-- Dynamically populate Location options -->
            {% for company_size in company_size_values %}
                <option value="{{ company_size }}">{{ company_size }}</option>
            {% endfor %}
        </select>

        <button type="submit">Predict</button><br><br>

        <h1>Predicted Salary (USD) : {{pred_result}}</h1>

    </form>

</body>
</html>

# %% [markdown]
# ## Streamlit

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,6,8,9,20])
],remainder='passthrough')
#[0,6,8,9,20] are columsn to be encoded
step2 = RandomForestClassifier(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
print('Accuracy',accuracy_score(y_test,y_pred))

# %% [markdown]
# #**From devika's internship project**

# %% [markdown]
# how to do feature selection
# 1. correlation
# 2.
# 3. Variance inflation factor

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# multicollinearity
#
# feature selection

# %% [markdown]
# ![image.png](data:image/png;base64,...)
